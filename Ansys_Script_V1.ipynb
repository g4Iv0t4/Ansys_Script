# %%
# !pip install pyautogui
# !pip install pyansys
# Import the ANSYS Scripting Interface module
# !pip install ansys.mapdl.core

# %%
import os
import time
import subprocess
import pyautogui
import win32api
import win32con
import tkinter as tk
from tkinter import messagebox

# %%
                  ######################## FUNCTIONS ###########################
# Define Menu function
click_menu = lambda: (35, 45)
click_create = lambda: (65, 45)

                  
                  ######################## CONSTANTS ###########################
# Define constants for mouse wheel movement
WHEEL_DELTA = 120
MOUSEEVENTF_WHEEL = 0x0800

# %%
# WORK BENCH
# THE GEOMETRY SOFTWARE MUST BE IN A NON FULL SCREEN MODE
'''
This section of the code is responsible for opening the software and 
waiting for 45 seconds until the geometry tab is loaded. Once the geometry tab is 
successfully loaded, the code will proceed to open the design modeler and display the 
import screen. However, it's important to note that the user will be required to manually 
import the body, as this cannot be automated through the code.

The resolution of the screen has to be set up as 1680 X 1050 and the scale as 125 %.
'''

# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Path to ANSYS Workbench executable file
workbench_path = "C:/Program Files/ANSYS Inc/v211/Framework/bin/Win64/runwb2.exe"
# Open Workbench in a separate process
subprocess.Popen(workbench_path)
# Wait for Workbench to open
time.sleep(45)
# Continue with executing the next lines of code in Python
# print("ANSYS Workbench is now open.")
# Move mouse to left side of the screen
pyautogui.moveTo(40, pyautogui.size()[1] / 2)
# Scroll down
pyautogui.scroll(-1550)
# Double click on Geometry tab
pyautogui.doubleClick(120, 445)
# Wait 
time.sleep(1)
# Right-click on Geometry tab
pyautogui.moveTo(415, 250)
pyautogui.click(button='right')
# Wait menu
time.sleep(.5)
# Move mouse down to open design modeler..
pyautogui.move(30, 30, duration=0.5)
# Click on design modeler geometry ... option
pyautogui.click()
# Wait to Design modeler to open
time.sleep(8)
# Create a message box with the desired text
messagebox.showinfo('Message', 'The software CANT be in a full screen mode', parent=None)
# Wait to Design modeler to open
time.sleep(8)
# #Full Screen
pyautogui.click(1590, 20)
# Get the File menu coordinates from the function
x, y = click_menu()
# Move mouse to File menu and click
pyautogui.moveTo(x, y)
pyautogui.click()
# Move mouse down to Import...
pyautogui.move(0, 180, duration=0.5)
# Click on Import External Geometry File
pyautogui.click()
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
pyautogui.moveTo(700, 445)
pyautogui.doubleClick()
time.sleep(.5)
# Move mouse to Generate
pyautogui.moveTo(420, 135)
pyautogui.click()
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Create a message box with the desired text
messagebox.showinfo('Message','Run the next cell and open DesignModeler.', parent=None)
# Out:
# 'ok'

# %%
# GEOMETRY
# THE GEOMETRY SOFTWARE MUST BE IN FULL SCREEN MODE
''' 
This section code is responsible for the creation of a 3D model in a CAD software. 
It clicks on specific locations and inputs numerical values to create a rectangular shape, 
adjust its size and location, extrude it, and then applies a Boolean operation. 
The resulting model is then named using a right-click menu.

The script begins by setting up a few input parameters, such as the length of the rectangular 
object and the distances of its edges from the front, back, and top of a reference object. 
It then uses the pyautogui library to simulate user actions on the CAD software, such as 
clicking on specific buttons, entering numerical values, and moving the mouse cursor to 
specific locations.

The script starts by clicking on the Z plane of the reference object and zooming out.
It then clicks on the Sketching tab and selects the Rectangle tool, clicks on the starting 
point of the rectangle, and drags the mouse cursor to draw the rectangle.
Next, it clicks on the Dimension tab and enters numerical values to define the distances 
from the front, back, and top edges of the rectangle to the reference object. It then clicks 
on the Extrude tab, applies the Boolean operation, and names the resulting model using a 
right-click menu. Finally, the script selects the top and front planes of the reference 
object and names them using the same right-click menu.
'''

                  ####################### INPUTS #######################
lenghtObj = '1.44' # 
distanceBehind = '10.5' # H2
distanceFront = '2.1' # H1
distanceVertical = '2'# V3
    
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Wait 
time.sleep(3)
# Click in the normal Z plane.
pyautogui.doubleClick(1550, 865)
# click empty space
pyautogui.click(600, 360)
# Simulate scrolling down
zoomOut = -34
win32api.mouse_event(MOUSEEVENTF_WHEEL, 0, 0, zoomOut * WHEEL_DELTA, 0)
# click on Sketching tab
pyautogui.click(60, 645)
# click on Rectangle
pyautogui.click(100, 360)
# Click and hold the left mouse button 
pyautogui.click(420, 600)
# Move the mouse to the right to do the rectangle
pyautogui.dragTo(1420, 450)
#click on Dimension tab
pyautogui.click(100, 560)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# H1 -> Distance from the end of rectangle to the front of the car 
pyautogui.click(420, 450)
pyautogui.click(1140, 400)
pyautogui.doubleClick(750, 400)
pyautogui.doubleClick(750, 300)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# H2 -> Distance from the begin of rectangle to the front of the car
pyautogui.click(1420, 450)
pyautogui.click(1145, 400)
pyautogui.doubleClick(1300, 400)
pyautogui.doubleClick(1300, 300)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# V1 -> Vertical distance of the rectangle
pyautogui.click(1420, 470)
pyautogui.doubleClick(1520, 470)
pyautogui.doubleClick(1500, 440)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Edit distance H1
pyautogui.click(160, 820)
# Enter the number "H1"
pyautogui.typewrite(distanceFront)
# Press the "Enter" key
pyautogui.press("enter")
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Edit distance H2
pyautogui.click(160, 840)
# Enter the number "H2"
pyautogui.typewrite(distanceBehind)
# Press the "Enter" key
pyautogui.press("enter")
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Edit distance V1
pyautogui.click(160, 860)
# Enter the number "V1"
pyautogui.typewrite(distanceVertical)
# Press the "Enter" key
pyautogui.press("enter")
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Click on Extrude tab
pyautogui.click(70, 160)
#Click on Operation
pyautogui.click(170, 770)
# Click Scroll down
pyautogui.click(370, 770)
time.sleep(.5)
# Click Add Frozen
pyautogui.click(320, 785)
# Move mouse to Generate
pyautogui.click(420, 135)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Get the File menu coordinates from the function
x, y = click_create()
# Move mouse to Create menu and click
pyautogui.moveTo(x, y)
pyautogui.click()
# Click Boolean
pyautogui.click(65, 435)
# Apply Boolean
pyautogui.click(150, 775)
#Click on Operation
pyautogui.click(170, 750)
# Click Scroll down
pyautogui.click(390, 750)
time.sleep(.5)
# Click Subtract
pyautogui.click(320, 780)
# Click Target Bodies
pyautogui.click(320, 770)
# Click + from Tree Outline
pyautogui.click(50, 375)
# Click second solid body
pyautogui.click(150, 420)
# Click apply
pyautogui.click(210, 776)
# Click tool Bodies
pyautogui.click(280, 790)
# #Click first solid body
pyautogui.click(150, 390)
# # Click apply
pyautogui.click(210, 786)
# Move mouse to Generate
pyautogui.click(420, 135)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Click in the Isometric View
pyautogui.click(1610, 800)
# Simulate zoom out
zoomOut = -30
win32api.mouse_event(MOUSEEVENTF_WHEEL, 0, 0, zoomOut * WHEEL_DELTA, 0)
#Simulate pressing Ctrl+F, select only faces
pyautogui.hotkey('ctrl', 'f')
# Hold down the control key
pyautogui.keyDown('ctrl')
# Click in the Plane front plane facing Z
pyautogui.click(840, 450)
# Click in the Plane top plane facing Z
pyautogui.click(840, 390)
# Release the control key
pyautogui.keyUp('ctrl')
# click empty space and right click
pyautogui.moveTo(600, 360)
pyautogui.click(button='right')
# Wait 
time.sleep(.5)
# Selectec Named Selection from right click menu
pyautogui.click(650, 855)
# Click in name selection option to change the name of the planes
pyautogui.click(200, 720)
# Enter the boundary condition name
pyautogui.typewrite('TopSide')
# Press the "Enter" key
pyautogui.press("enter")
# Press the "F5" key to generate
pyautogui.press("F5")
# Hold down the control key
pyautogui.keyDown('ctrl')
# Click in the Plane front plane facing Z
pyautogui.click(840, 450)
# Click in the Plane top plane facing Z
pyautogui.click(840, 390)
# Release the control key
pyautogui.keyUp('ctrl')
# # Press the "F8" key to Hide Face(s)
pyautogui.press("F8")
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Click in the Floor Plane facing Z
pyautogui.click(840, 490)
# click empty space and right click
pyautogui.moveTo(600, 360)
pyautogui.click(button='right')
# Wait 
time.sleep(.5)
# Selectec Named Selection from right click menu
pyautogui.click(650, 925)
# Click in name selection option to change the name of the planes
pyautogui.click(200, 720)
# Enter the boundary condition name
pyautogui.typewrite('floor')
# Press the "Enter" key
pyautogui.press("enter")
# Press the "F5" key to generate
pyautogui.press("F5")
# Click in the Floor Plane facing Z
pyautogui.click(840, 490)
# Press the "F8" key to Hide Face(s)
pyautogui.press("F8")
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Click in the Inlet Plane facing Z
pyautogui.click(790, 440)
# click empty space and right click
pyautogui.moveTo(600, 360)
pyautogui.click(button='right')
# Wait 
time.sleep(.5)
# Selectec Named Selection from right click menu
pyautogui.click(650, 925)
# Click in name selection option to change the name of the planes
pyautogui.click(200, 720)
# Enter the boundary condition name
pyautogui.typewrite('Inlet')
# Press the "Enter" key
pyautogui.press("enter")
# Press the "F5" key to generate
pyautogui.press("F5")
# Click in the Inlet Plane facing Z
pyautogui.click(790, 440)
# Press the "F8" key to Hide Face(s)
pyautogui.press("F8")
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Click in the Outlet Plane facing Z
pyautogui.click(1290, 740)
# click empty space and right click
pyautogui.moveTo(600, 360)
pyautogui.click(button='right')
# Wait 
time.sleep(.5)
# Selectec Named Selection from right click menu
pyautogui.click(650, 925)
# Click in name selection option to change the name of the planes
pyautogui.click(200, 720)
# Enter the boundary condition name
pyautogui.typewrite('Outlet')
# Press the "Enter" key
pyautogui.press("enter")
# Press the "F5" key to generate
pyautogui.press("F5")
#Click in the Outlet Plane facing Z
pyautogui.click(1290, 740)
# Press the "F8" key to Hide Face(s)
pyautogui.press("F8")
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Click in the Plane symmetric facing Z
pyautogui.click(840, 450)
# click empty space and right click
pyautogui.moveTo(600, 360)
pyautogui.click(button='right')
# Wait 
time.sleep(.5)
# Selectec Named Selection from right click menu
pyautogui.click(650, 925)
# Click in name selection option to change the name of the planes
pyautogui.click(200, 720)
# Enter the boundary condition name
pyautogui.typewrite('Symmetric')
# Press the "Enter" key
pyautogui.press("enter")
# Press the "F5" key to generate
pyautogui.press("F5")
# # Click in the symmetric Plane plane facing Z
pyautogui.click(840, 450)
# Press the "F8" key to Hide Face(s)
pyautogui.press("F8")
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Click in the normal Z plane.
pyautogui.doubleClick(1550, 865)
# click empty space
pyautogui.click(700, 360)
time.sleep(.5)
# Simulate zoom in
zoomOut = 4
win32api.mouse_event(MOUSEEVENTF_WHEEL, 0, 0, zoomOut * WHEEL_DELTA, 0)
# Move the mouse to the starting position
pyautogui.moveTo(490, 500)
# Hold down the Ctrl key
pyautogui.keyDown('ctrl')
# Click the mouse wheel button
pyautogui.mouseDown(button='middle')
# Drag the mouse to the right side
pyautogui.moveTo(990, 500, duration = .4)
# Release the mouse button
pyautogui.mouseUp(button='middle')
# Release the Ctrl key
pyautogui.keyUp('ctrl')
# Simulate zoom in
zoomOut = 10
win32api.mouse_event(MOUSEEVENTF_WHEEL, 0, 0, zoomOut * WHEEL_DELTA, 0)
# Move the mouse to the starting position
pyautogui.moveTo(1390, 850)
# Hold down the Ctrl key
pyautogui.keyDown('ctrl')
# Click the mouse wheel button
pyautogui.mouseDown(button='middle')
# Drag the mouse to the right side
pyautogui.moveTo(740, 200, duration = .4)
# Release the mouse button
pyautogui.mouseUp(button='middle')
# Release the Ctrl key
pyautogui.keyUp('ctrl')
# Chnage the angle of the car
# Move the mouse to the starting position
pyautogui.moveTo(1000, 350)
# Click the mouse wheel button
pyautogui.mouseDown(button='middle')
# Drag the mouse to the right side
pyautogui.moveTo(1100, 400, duration = .4)
# Release the mouse button
pyautogui.mouseUp(button='middle')
# Hold down the Ctrl key
pyautogui.keyDown('ctrl')
# Select Top faces of the car
pyautogui.moveTo(1150,640)
pyautogui.click()
time.sleep(1)
pyautogui.moveTo(1170,600)
pyautogui.click()
pyautogui.click(1270,585)
pyautogui.click(1640,520)
#Release the Ctrl key
pyautogui.keyUp('ctrl')
# click empty space and right click
pyautogui.moveTo(600, 360)
pyautogui.click(button='right')
# Wait 
time.sleep(.5)
# Selectec Named Selection from right click menu
pyautogui.click(650, 880)
# Click in name selection option to change the name of the planes
pyautogui.click(200, 720)
# Enter the boundary condition name
pyautogui.typewrite('AhmedTop')
# Press the "Enter" key
pyautogui.press("enter")
# Press the "F5" key to generate
pyautogui.press("F5")
# Hold down the Ctrl key
pyautogui.keyDown('ctrl')
# Select Top faces of the car
pyautogui.click(1150,640)
pyautogui.click(1170,600)
pyautogui.click(1270,585)
pyautogui.click(1640,520)
# Release the Ctrl key
pyautogui.keyUp('ctrl')
# Press the "F8" key to Hide Face(s)
pyautogui.press("F8")
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Move the mouse to the starting position
pyautogui.moveTo(1290, 500)
# Hold down the Ctrl key
pyautogui.keyDown('ctrl')
# Click the mouse wheel button
pyautogui.mouseDown(button='middle')
# Drag the mouse to the right side
pyautogui.moveTo(890, 500, duration = .4)
# Release the mouse button
pyautogui.mouseUp(button='middle')
# Release the Ctrl key
pyautogui.keyUp('ctrl')
# Hold down the Ctrl key
pyautogui.keyDown('ctrl')
# Select side faces of the car
pyautogui.moveTo(800,650)
pyautogui.click()
pyautogui.moveTo(1150,640)
pyautogui.click()
time.sleep(1)
pyautogui.moveTo(1145,730)
pyautogui.click()
pyautogui.click(885,760)
#Release the Ctrl key
pyautogui.keyUp('ctrl')
# click empty space and right click
pyautogui.moveTo(600, 360)
pyautogui.click(button='right')
# Wait 
time.sleep(.5)
# Selectec Named Selection from right click menu
pyautogui.click(650, 880)
# Click in name selection option to change the name of the planes
pyautogui.click(200, 720)
# Enter the boundary condition name
pyautogui.typewrite('AhmedSide')
# Press the "Enter" key
pyautogui.press("enter")
# Press the "F5" key to generate
pyautogui.press("F5")
# Hold down the Ctrl key
pyautogui.keyDown('ctrl')
# Select side faces of the car
pyautogui.moveTo(800,650)
pyautogui.click()
pyautogui.moveTo(1150,640)
pyautogui.click()
time.sleep(1)
pyautogui.moveTo(1145,730)
pyautogui.click()
pyautogui.click(885,760)
#Release the Ctrl key
pyautogui.keyUp('ctrl')
# Press the "F8" key to Hide Face(s)
pyautogui.press("F8")
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Hold down the Ctrl key
pyautogui.keyDown('ctrl')
# Select side faces of the car
pyautogui.click(780,725)
pyautogui.click(980,725)
pyautogui.click(1330,650)
#Release the Ctrl key
pyautogui.keyUp('ctrl')
time.sleep(1)
# click empty space and right click
pyautogui.moveTo(600, 360)
pyautogui.click(button='right')
# Wait 
time.sleep(.5)
# Selectec Named Selection from right click menu
pyautogui.moveTo(650, 880)
pyautogui.click()
# Click in name selection option to change the name of the planes
pyautogui.click(200, 720)
# Enter the boundary condition name
pyautogui.typewrite('AhmedBottom')
# Press the "Enter" key
pyautogui.press("enter")
# Press the "F5" key to generate
pyautogui.press("F5")
# Hold down the Ctrl key
pyautogui.keyDown('ctrl')
# Select side faces of the car
pyautogui.click(780,725)
pyautogui.click(980,725)
pyautogui.click(1330,650)
#Release the Ctrl key
pyautogui.keyUp('ctrl')
# Press the "F8" key to Hide Face(s)
pyautogui.press("F8")
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Press the "Alt + F4" key
# pyautogui.hotkey('alt', 'f4')
# # Wait
# time.sleep(1.5)
# Save it !
# pyautogui.hotkey('ctrl', 's')
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Create a message box with the desired text
messagebox.showinfo('Message', 'Geometry is ready!\nClose the DesignModeler.\nRun the next cell and open WorkBench.', parent=None)

# %%
# ICEM CFD
''' 
The script imports the time and pyautogui libraries and sets some input parameters such as 
the scaleFactor, globalElementSeedSize, maxSize, scaleFacX, scaleFacY, scaleFacZ, 
scaleFacXOffSet, boxOne, boxTwo, numberLayer, tetraMesh, hexaMesh, and numberCores.

After setting up the input parameters, the script uses pyautogui to simulate 
mouse and keyboard actions to create a mesh in ICEM CFD software. The script waits for a 
specific amount of time at several points to allow the software to load or complete a 
specific operation before proceeding with the next action. The steps performed by the 
script are as follows:

1.The script opens ICEM CFD software by simulating a double-click on the software icon.
2.The script selects the Geometry tab in the software by simulating a mouse action.
3.The script connects the Geometry by simulating a mouse action and holds down the left 
mouse button.
4.The script selects ICEM CFD by simulating a double-click on the software icon.
5.The script waits for the software to open.
6.The script clicks on Solid Simple Display.
7.The script clicks on the Geometry tree.
8.The script clicks on Surfaces.
9.The script clicks on Parts.
10.The script hides Inlet, Outlet, Top, and Solid by simulating double-click actions 
on the respective parts.
11.The script changes the view to Iso.
12.The script clicks on Create Body and changes the name of the part to Body.
13.The script selects two points in the box and simulates a middle mouse button press.
14.The script enters full-screen mode and confirms the selection.
15.The script clicks on Repair Geometry.
16.The script confirms the selection.
17.The script clicks on the Mesh Tab.
18.The script clicks on Global Mesh Setup and sets the scaleFactor and globalElementSeedSize.
19.The script clicks on Part Mesh Setup and sets the maxSize for each element.
20.The script creates a mesh density and updates the size mesh.
21.The script dismisses the Create Mesh Density window.
22.The script clicks on Create Mesh.
23.The script confirms the selection.
24.The script waits for the meshing process to complete.
25.The script saves and exits the software.
Overall, the script automates the process of creating a mesh in ICEM CFD software for a specific geometry by simulating mouse and keyboard actions. The input parameters can be modified to suit different geometries and meshing requirements.
'''

                  ####################### INPUTS #######################


scaleFactor = '1'
globalElementSeedSize = '0.1'
maxSize = '.001'
scaleFacX = '3.8'
scaleFacY = '1.2'
scaleFacZ = '1.2'
scaleFacXOffSet = '1.2'
boxOne = '0.02'
boxTwo = '0.001'
numberLayer = '3'
tetraMesh = True
hexaMesh = False
numberCores = '8'
    
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Wait
time.sleep(3)
# Select ICEM CFD
pyautogui.moveTo(80, 500)
pyautogui.doubleClick()
# Move to Geometry tab
pyautogui.moveTo(415, 250)
# Hold down the  key to connect the Geometry 
pyautogui.mouseDown(button='left')
pyautogui.moveTo(415, 400, duration = 1)
# Release the key
pyautogui.mouseUp(button='left')
# Move to ICEM CFD
pyautogui.moveTo(615, 250)
pyautogui.doubleClick()
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Wait for the ICEM CFD to open
time.sleep(42)
# Click in Solid Simple Display
pyautogui.moveTo(235, 130)
pyautogui.click()
# # Click in Geometry tree
pyautogui.click(41, 197)
time.sleep(.5)

# Click in surfaces
pyautogui.click(80, 270)
time.sleep(.5)
# Click in Parts
pyautogui.click(40, 290)
# Click to hide Inlet, Outlet, Top
pyautogui.doubleClick(120, 385) # Inlet
time.sleep(.5)
pyautogui.doubleClick(120, 400) # Outlet
time.sleep(.5)
pyautogui.doubleClick(120, 460) # Top
time.sleep(.5)
pyautogui.doubleClick(120, 420) # solid
time.sleep(.5)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Change view to Iso
pyautogui.moveTo(1606, 739, duration = 1)
time.sleep(1)
pyautogui.doubleClick()
# Click in Create Body
pyautogui.click(390, 120) 
time.sleep(1)
# Change the name of the part
pyautogui.moveTo(90, 660)
time.sleep(.3)
pyautogui.click()
# Enter the name
pyautogui.typewrite('Body')
time.sleep(.3)
# Click Apply
pyautogui.click(310, 895)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Select 2 points in the box
pyautogui.click(580, 315)
pyautogui.click(1475, 725)
# Bring the mouse to an empty space
pyautogui.moveTo(838, 622)
# Press the middle mouse button
pyautogui.mouseDown(button='middle')
# Release the middle mouse button
pyautogui.mouseUp(button='middle')
time.sleep(1)
#Full Screen
pyautogui.click(1590, 20)
# Ok selection
pyautogui.click(190, 980)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Click repair geometry
pyautogui.moveTo(445, 120)
pyautogui.click()
time.sleep(2)
# Ok selection
pyautogui.click(190, 980)
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Click in Mesh Tab
pyautogui.moveTo(350, 80)
pyautogui.click()
# Click in global mesh setup
pyautogui.moveTo(280, 110)
pyautogui.click()
# Change the factor
pyautogui.moveTo(160, 785)
time.sleep(.5)
pyautogui.click()
time.sleep(.3)
pyautogui.press(['backspace', 'backspace', 'backspace'])
# Choose the scale factor
pyautogui.typewrite(scaleFactor)
# Choose the global Element Seed Size
pyautogui.moveTo(160, 900)
time.sleep(.3)
pyautogui.click()
time.sleep(.3)
pyautogui.press(['backspace', 'backspace', 'backspace'])
time.sleep(.3)
pyautogui.typewrite(globalElementSeedSize)
# Apply
pyautogui.moveTo(120, 970)
time.sleep(.5)
pyautogui.click()

# Click part Mesh setup
pyautogui.moveTo(320, 120)
time.sleep(.5)
pyautogui.click()

# Input the maximum size for each element
# BOTTOM
pyautogui.moveTo(570, 170)
time.sleep(.3)
pyautogui.click()
pyautogui.press('backspace')
pyautogui.typewrite(maxSize)
time.sleep(.3)
# SIDES
pyautogui.moveTo(570, 200)
time.sleep(.3)
pyautogui.click()
pyautogui.press('backspace')
pyautogui.typewrite(maxSize)
time.sleep(.3)
# TOP
pyautogui.moveTo(570, 210)
time.sleep(.3)
pyautogui.click()
pyautogui.press('backspace')
pyautogui.typewrite(maxSize)
time.sleep(.3)
# Apply
pyautogui.moveTo(870, 530)
time.sleep(.3)
pyautogui.click()
# Dismiss
pyautogui.moveTo(970, 530)
time.sleep(.3)
pyautogui.click()
# Click in Create mesh density
pyautogui.moveTo(410, 120)
time.sleep(.3)
pyautogui.click()
time.sleep(.3)
# Update the size mesh
pyautogui.moveTo(115, 675)
time.sleep(.1)
pyautogui.click()
pyautogui.press(['backspace', 'backspace', 'backspace', 'backspace', 'backspace'])
pyautogui.typewrite(boxOne)
time.sleep(.1)
# Click in entity bounds
pyautogui.moveTo(120, 830)
pyautogui.click()
time.sleep(.3)
# Select geometry
pyautogui.moveTo(300, 865)
pyautogui.click()
time.sleep(.3)
# In order to select the box, place the mouse in the origin position
pyautogui.moveTo(700, 270)
pyautogui.mouseDown(button='left')
pyautogui.moveTo(825, 415)
# # Release the mouse button
pyautogui.mouseUp(button='left')
time.sleep(.3)
# click empty space
pyautogui.moveTo(500, 400)
pyautogui.click(button='middle')
time.sleep(.5)
# Apply
pyautogui.moveTo(120, 970)
time.sleep(.3)
pyautogui.click()
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# # Click in geometry tab
pyautogui.moveTo(290, 80)
time.sleep(.1)
pyautogui.click()
# # Click in transform geometry
pyautogui.moveTo(470, 120)
time.sleep(.1)
pyautogui.click()
# Select geometry
pyautogui.moveTo(290, 640)
time.sleep(.1)
pyautogui.click()
# Select the density box
pyautogui.moveTo(740, 300)
time.sleep(.1)
pyautogui.click()
# click empty space
pyautogui.moveTo(500, 400)
pyautogui.click(button='middle')
time.sleep(.3)
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Click in scale geometry
pyautogui.moveTo(170, 750)
time.sleep(.1)
pyautogui.click()
# Move the mouse to the scroll bar
pyautogui.moveTo(360, 750)
# Hold down the  key to connect the Geometry 
pyautogui.mouseDown(button='left')
pyautogui.moveTo(360, 830, duration = .1)
# Release the key
pyautogui.mouseUp(button='left')

# X Factor
pyautogui.moveTo(160, 755)
time.sleep(.1)
pyautogui.click()
pyautogui.press('backspace')
pyautogui.typewrite(scaleFacX)
time.sleep(.1)

# Y Factor
pyautogui.moveTo(160, 790)
time.sleep(.1)
pyautogui.click()
pyautogui.press('backspace')
pyautogui.typewrite(scaleFacY)
time.sleep(.1)

# Z Factor
pyautogui.moveTo(160, 820)
time.sleep(.1)
pyautogui.click()
pyautogui.press('backspace')
pyautogui.typewrite(scaleFacZ)
time.sleep(.1)
# Chnage the center point to Centroid
pyautogui.moveTo(305, 905)
time.sleep(.1)
pyautogui.click()
pyautogui.moveTo(140, 955)
time.sleep(.1)
pyautogui.click()
# Apply
pyautogui.moveTo(120, 970)
time.sleep(.1)
pyautogui.click()
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Move the mouse to the scroll bar
pyautogui.moveTo(360, 830) 
# Hold down the key 
pyautogui.mouseDown(button='left')
pyautogui.moveTo(360, 750, duration = .1)
# Release the key
pyautogui.mouseUp(button='left')
# Select Translate Geometry
pyautogui.moveTo(40, 750)
time.sleep(.1)
pyautogui.click()
# Move the mouse to the scroll bar
pyautogui.moveTo(360, 750)
# Hold down the key 
pyautogui.mouseDown(button='left')
pyautogui.moveTo(360, 830, duration = .1)
# Release the key
pyautogui.mouseUp(button='left')
# X Factor
pyautogui.moveTo(160, 835)
time.sleep(.1)
pyautogui.click()
pyautogui.press('backspace')
pyautogui.typewrite(scaleFacXOffSet)
time.sleep(.1)
# Apply
pyautogui.moveTo(120, 970)
time.sleep(.1)
pyautogui.click()
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Click in Mesh Tab
pyautogui.moveTo(350, 80)
pyautogui.click()
# Click in Create mesh density
pyautogui.moveTo(410, 120)
time.sleep(.1)
pyautogui.click()
time.sleep(.1)
# Update the size mesh
pyautogui.moveTo(115, 675)
time.sleep(.1)
pyautogui.click()
pyautogui.press(['backspace', 'backspace', 'backspace', 'backspace', 'backspace'])
pyautogui.typewrite(boxTwo)
time.sleep(.1)
# Turn off the densities
pyautogui.click(70, 295)
time.sleep(.1)
# Turn off the body
pyautogui.click(70, 275)
time.sleep(.1)
# Click in entity bounds
pyautogui.moveTo(120, 830)
pyautogui.click()
time.sleep(.5)
# Select geometry
pyautogui.moveTo(300, 865)
pyautogui.click()
time.sleep(.5)
# Select the back of the car
pyautogui.moveTo(775, 330)
time.sleep(.2)
pyautogui.click()
# click empty space
pyautogui.moveTo(500, 400)
pyautogui.click(button='middle')
time.sleep(.5)
# Apply
pyautogui.moveTo(120, 970)
time.sleep(.1)
pyautogui.click()
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Click part Mesh setup
pyautogui.moveTo(320, 120)
time.sleep(.5)
pyautogui.click()
# Apply Prism
# AHMEDBOTTOM
pyautogui.moveTo(365, 170)
time.sleep(.1)
pyautogui.click()
# AHMEDSIDE
pyautogui.moveTo(365, 190)
time.sleep(.1)
pyautogui.click()
# AHMEDTOP
pyautogui.moveTo(365, 215)
time.sleep(.1)
pyautogui.click()
# FLOOR
pyautogui.moveTo(365, 255)
time.sleep(.1)
pyautogui.click()
# TOPSIDE
pyautogui.moveTo(365, 360)
time.sleep(.1)
pyautogui.click()
# # Update Layer number
# TOPSIDE
pyautogui.moveTo(805, 360)
time.sleep(.1)
pyautogui.click()
pyautogui.press('backspace')
pyautogui.typewrite(numberLayer)
time.sleep(.1)

# FLOOR
pyautogui.moveTo(805, 255)
time.sleep(.1)
pyautogui.click()
pyautogui.press('backspace')
pyautogui.typewrite(numberLayer)
time.sleep(.1)

# AHMEDTOP
pyautogui.moveTo(805, 215)
time.sleep(.1)
pyautogui.click()
pyautogui.press('backspace')
pyautogui.typewrite(numberLayer)
time.sleep(.1)

# AHMEDSIDE
pyautogui.moveTo(805, 190)
time.sleep(.1)
pyautogui.click()
pyautogui.press('backspace')
pyautogui.typewrite(numberLayer)
time.sleep(.1)

# AHMEDBOTTOM
pyautogui.moveTo(805, 170)
time.sleep(.1)
pyautogui.click()
pyautogui.press('backspace')
pyautogui.typewrite(numberLayer)
time.sleep(.1)
# Apply
pyautogui.moveTo(870, 530)
time.sleep(.5)
pyautogui.click()
# Dismiss
pyautogui.moveTo(970, 530)
time.sleep(.5)
pyautogui.click()
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #

# Go to settings
pyautogui.moveTo(210, 50)
time.sleep(.1)
pyautogui.click()
# General
pyautogui.moveTo(250, 80)
time.sleep(.1)
pyautogui.click()
# Number of processors
pyautogui.moveTo(210, 660)
time.sleep(.1)
pyautogui.click()
pyautogui.press('backspace')
# Choose number of cores
pyautogui.typewrite(numberCores)
# Ok selection
pyautogui.click(190, 980)
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Click in Create mesh density
pyautogui.moveTo(510, 120)
time.sleep(.1)
pyautogui.click()
time.sleep(.1)

#  Mesh type
if tetraMesh is True:
    # Compute
    pyautogui.moveTo(110, 980)
    time.sleep(.1)
    pyautogui.click()

elif hexaMesh is True:
    pyautogui.moveTo(110, 750)
    time.sleep(.1)
    pyautogui.click()
    pyautogui.moveTo(110, 795)
    time.sleep(.1)
    pyautogui.click()
    pyautogui.moveTo(110, 980)
    time.sleep(.1)
    pyautogui.click()

    
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
messagebox.showinfo('Message', 'Wait for the mesh, and run the next cell.\nReturn to ICEM.', parent=None)

# %%
''' 

'''
# ICEM CFD
time.sleep(3)

#Click in Prism Mesh
pyautogui.moveTo(130, 665)
time.sleep(.1)
pyautogui.click()
# Compute
pyautogui.moveTo(110, 980)
time.sleep(.1)
pyautogui.click()
#clikc No to save it
pyautogui.moveTo(830, 655)
time.sleep(.1)
pyautogui.click()

#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
#Full Screen
pyautogui.click(1590, 20)
# Ok selection
pyautogui.click(190, 980)
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
messagebox.showinfo('Message', 'Wait for the mesh!\nClose ICEM, run the next cell.\nOpen the WorkBench.', parent=None)

# %%
''' 
The first part of the code sets up the inputs for the simulation,
such as the frontal area and the number of iterations.

The code then uses PyAutoGUI to interact with the GUI of 
Fluent. It first waits for 3 seconds, then moves the mouse cursor 
to the position of the Fluent icon and clicks it. After waiting for 6 seconds, 
it selects the number of CPU cores to use and sets it to a value specified in the code.

The code then waits for the software to open and hides a wall. It then clicks 
through various menus and options to set up the simulation parameters, 
such as the turbulence model and boundary conditions.

Next, it sets the reference area for the simulation and initializes 
the solution. Finally, it clicks the "run calculation" button and sets 
the number of iterations to perform before starting the simulation.
Overall, this code is a script that automates the process of setting 
up and running a CFD simulation in Fluent, saving the user time and effort.
'''

# FLUENT
                  ####################### INPUTS #######################
    

frontalArea = '0.05604507' # m^2
interationNumber = '200'

#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Wait
time.sleep(3)
# Select Fluent
pyautogui.moveTo(80, 395)
#Hold down the key 
pyautogui.mouseDown(button='left')
pyautogui.moveTo(560, 250, duration = 1)
# Release the key
pyautogui.mouseUp(button='left')
time.sleep(.2)
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Select Setup
pyautogui.doubleClick(800, 255)
# Wait
time.sleep(6)
# Change number of cores
pyautogui.moveTo(1020, 575)
time.sleep(.1)
pyautogui.click()
pyautogui.press('backspace')
# Choose number of cores
pyautogui.typewrite(numberCores)

# Select Start
pyautogui.moveTo(740, 695)
time.sleep(.1)
pyautogui.click()
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Wait for the software to open
time.sleep(28)
# Hide the top wall
pyautogui.moveTo(1090, 505)
time.sleep(1)
pyautogui.click()
pyautogui.moveTo(1490, 450)
time.sleep(1)
pyautogui.click()
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Click in Models
pyautogui.moveTo(110, 350)
time.sleep(.5)
pyautogui.doubleClick()
# Click in Viscous
pyautogui.moveTo(330, 380)
time.sleep(.5)
pyautogui.doubleClick()
time.sleep(3)
# Click in k-epsilon (2 eqn)
pyautogui.moveTo(630, 270)
time.sleep(.5)
pyautogui.click()
# Click in k-epsilon Model -> Realizable
pyautogui.moveTo(600, 515)
time.sleep(.5)
pyautogui.click()
# Click in non-equilibrium wall function 
pyautogui.moveTo(590, 610)
time.sleep(.5)
pyautogui.click()
# Click in OK
pyautogui.moveTo(760, 800)
time.sleep(.2)
pyautogui.click()
time.sleep(4)
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Click Boundary Conditions
pyautogui.moveTo(110, 700)
time.sleep(.5)
pyautogui.doubleClick()
time.sleep(1.5)
# Click Inlet
pyautogui.moveTo(320, 425)
time.sleep(.5)
pyautogui.click()
time.sleep(1.5)
# Go to Edit
pyautogui.moveTo(360, 800, duration = 1)
time.sleep(.5)
pyautogui.click()
time.sleep(3)
# Change the velocity method to component
pyautogui.moveTo(520, 640, duration = 1)
time.sleep(.3)
pyautogui.click()
pyautogui.moveTo(520, 675, duration = .5)
time.sleep(.3)
pyautogui.click()
# Input 20 m/s in x
pyautogui.moveTo(820, 500, duration = 1)
pyautogui.doubleClick()
time.sleep(.5)
pyautogui.press('backspace')
time.sleep(.5)
pyautogui.click()
pyautogui.typewrite('20')
# CLick Apply
pyautogui.moveTo(790, 730)
time.sleep(.3)
pyautogui.doubleClick()
time.sleep(.3)
# CLick Close
pyautogui.moveTo(850, 730)
time.sleep(.3)
pyautogui.doubleClick()
time.sleep(3)
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# CLick reference values
pyautogui.moveTo(110, 765)
time.sleep(.3)
pyautogui.doubleClick()
time.sleep(1)
# Click in Compute from -> Inlet
pyautogui.moveTo(610, 340)
time.sleep(.3)
pyautogui.click()
pyautogui.moveTo(410, 425, duration = 1)
pyautogui.click()
# CLick in Area
pyautogui.moveTo(510, 385, duration = .5)
pyautogui.click()
pyautogui.press('backspace')
pyautogui.typewrite(frontalArea)
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# CLick in Solution Initialization
pyautogui.moveTo(260, 385)
# Click the mouse left button
pyautogui.mouseDown(button='left')
# Drag the mouse to the bottom side
pyautogui.moveTo(260, 460, duration = .4)
# Release the mouse button
pyautogui.mouseUp(button='left')
# Double click in Initialization
pyautogui.moveTo(150, 860)
time.sleep(.3)
pyautogui.doubleClick()
time.sleep(1)
# Click in Initialize
pyautogui.moveTo(420, 400, duration = .6)
time.sleep(.3)
pyautogui.click()
time.sleep(25)
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
# Click in Run Calculation
pyautogui.moveTo(120, 900, duration = .6)
time.sleep(.3)
pyautogui.doubleClick()
# Number of Interations
pyautogui.moveTo(320, 570, duration = 1)
pyautogui.click()
pyautogui.press('backspace')
pyautogui.typewrite(interationNumber)
# Click In calculate
pyautogui.moveTo(450, 790)
pyautogui.click()
